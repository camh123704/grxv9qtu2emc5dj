# %% [markdown]
# # Audio Transcription

# %%
from offline_transcription import transcribe_segments
jpath, mdpath, merged = transcribe_segments(
    audio_path="AUG_17_CLIF.wav",
    outdir="out",
    asr_model="/home/jovyan/Oracle_local/models/whisper-large-v3",
    device_choice="cuda",
    language="en",
    task="transcribe",
    chunk_length_s=30,
    stride_left_s=5,
    stride_right_s=2,
)
print("JSON:", jpath)
print("MD  :", mdpath)
print("Utterances:", len(merged))
# Out:
# ASR by segment:   0%|          | 0/360 [00:00<?, ?it/s]/home/jovyan/venvs/hfmeet/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# You have passed task=transcribe, but also have set `forced_decoder_ids` to [[1, None], [2, 50360]] which creates a conflict. `forced_decoder_ids` will be ignored in favor of task=transcribe.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ...

# %%
import json

src = "out/meeting_transcript.json"
dst = "out/meeting_transcript_nowords.json"

with open(src, "r", encoding="utf-8") as f:
    data = json.load(f)

if isinstance(data, list):
    for u in data:
        if isinstance(u, dict):
            u.pop("words", None)
else:
    if isinstance(data, dict):
        data.pop("words", None)

with open(dst, "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=2)
