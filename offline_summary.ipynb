# %% [markdown]
# # LLM Summary

# %%
# %run offline_summary2.py \
  --transcript out/AUG_23_meeting_transcript_nowords.json \
  --outdir out \
  --model_path models/llama-3.1-8b-instruct \
  --dtype bf16 \
  --num_predict 3500 \
  --temperature 0.2 \
  --top_p 0.9
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Wrote: out/meeting_ops_brief.md
